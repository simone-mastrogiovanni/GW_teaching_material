# %% [markdown]
# Run this notebook on [Google Colab](https://colab.research.google.com/github/simone-mastrogiovanni/GW_teaching_material/blob/master/population_inference/gaussian_example.ipynb)
#
# # Mean of a Gaussian process with icarogw
#
# In this tutorial we are going to estimate the mean of a Gaussian process in presence of selection biases using icarogw. We are in the following situation
#
# * A gaussian process with unkown mean $\mu_*=0$ and known variance $\sigma^2_*=1$ generates numbers $x$ with a rate $R_x$ of 100 samples per second. The samples rate per unit time can be written as
#
# $$\frac{dN}{dxdt}=R_x \mathcal{N}(x|\mu_*=0.,\sigma^2_*=1)$$
#
# * Our detector does not directly register the $x$ values, but it instead it register a value $y$ contaminated by the noise. The likelihood of obtaining $y$ given $x$ is given by a random gaussian process.
#
# $$\mathcal{L}_{\rm noise}(y|x)=\mathcal{N}(y|\mu=x,\sigma^2_n=1)$$
#
# * Moreover, our detector is able only to register values of $y \in [-1,1]$
#
# * Our task is to estimate the mean  $\mu_*$ of the original gaussian process with icarogw
#
# To perform the population inference, we are going to use [icarogw](https://github.com/simone-mastrogiovanni/icarogw), a python package for population inference in presence of selection bias.

# %%
# Uncomment the line below to install icarogw 
# ! pip install git+https://github.com/simone-mastrogiovanni/icarogw.git
# Out:
# Collecting git+https://github.com/simone-mastrogiovanni/icarogw.git
#   Cloning https://github.com/simone-mastrogiovanni/icarogw.git to /tmp/pip-req-build-dco9p4t6
#   Running command git clone --filter=blob:none --quiet https://github.com/simone-mastrogiovanni/icarogw.git /tmp/pip-req-build-dco9p4t6
#   Resolved https://github.com/simone-mastrogiovanni/icarogw.git to commit cdb9d446692f679482e5606cf34454f58732c4db
#   Preparing metadata (setup.py) ... done
# Collecting bilby>=2.1.0
#   Using cached bilby-2.1.1-py3-none-any.whl (2.3 MB)
# Collecting healpy>=1.16.2
#   Downloading healpy-1.16.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 2.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting mpmath>=1.3.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting ligo.skymap>=1.0.7
#   Using cached ligo.skymap-1.0.7-cp38-abi3-manylinux_2_28_x86_64.whl (21.4 MB)
# Collecting ChainConsumer
#   Using cached ChainConsumer-0.34.0.tar.gz (43 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: corner in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from bilby>=2.1.0->icarogw==2.0.1) (2.2.1)
# Requirement already satisfied: tqdm in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from bilby>=2.1.0->icarogw==2.0.1) (4.64.1)
# Requirement already satisfied: matplotlib>=2.1 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from bilby>=2.1.0->icarogw==2.0.1) (3.6.2)
# Requirement already satisfied: emcee in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from bilby>=2.1.0->icarogw==2.0.1) (3.1.3)
# Requirement already satisfied: scipy>=1.5 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from bilby>=2.1.0->icarogw==2.0.1) (1.8.1)
# Requirement already satisfied: attrs in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from bilby>=2.1.0->icarogw==2.0.1) (22.1.0)
# Requirement already satisfied: dill in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from bilby>=2.1.0->icarogw==2.0.1) (0.3.3)
# Collecting dynesty>=2.0.1
#   Using cached dynesty-2.1.2-py2.py3-none-any.whl (106 kB)
# Requirement already satisfied: pandas in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from bilby>=2.1.0->icarogw==2.0.1) (1.5.1)
# Requirement already satisfied: h5py in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from bilby>=2.1.0->icarogw==2.0.1) (3.7.0)
# Requirement already satisfied: bilby.cython>=0.3.0 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from bilby>=2.1.0->icarogw==2.0.1) (0.3.0)
# Requirement already satisfied: numpy in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from bilby>=2.1.0->icarogw==2.0.1) (1.22.4)
# Requirement already satisfied: astropy in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from healpy>=1.16.2->icarogw==2.0.1) (5.1.1)
# Requirement already satisfied: ligo-segments>=1.2.0 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo.skymap>=1.0.7->icarogw==2.0.1) (1.4.0)
# Requirement already satisfied: astroplan>=0.7 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo.skymap>=1.0.7->icarogw==2.0.1) (0.8)
# Requirement already satisfied: pillow>=2.5.0 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo.skymap>=1.0.7->icarogw==2.0.1) (9.2.0)
# Requirement already satisfied: astropy-healpix>=0.3 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo.skymap>=1.0.7->icarogw==2.0.1) (0.7)
# Requirement already satisfied: ptemcee in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo.skymap>=1.0.7->icarogw==2.0.1) (1.0.0)
# Requirement already satisfied: python-ligo-lw>=1.8.0 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo.skymap>=1.0.7->icarogw==2.0.1) (1.8.3)
# Requirement already satisfied: ligo-gracedb>=2.0.1 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo.skymap>=1.0.7->icarogw==2.0.1) (2.8.0)
# Requirement already satisfied: reproject>=0.3.2 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo.skymap>=1.0.7->icarogw==2.0.1) (0.9.1)
# Requirement already satisfied: lalsuite!=7.2,>=6.82 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo.skymap>=1.0.7->icarogw==2.0.1) (7.11)
# Requirement already satisfied: pytz in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo.skymap>=1.0.7->icarogw==2.0.1) (2022.6)
# Requirement already satisfied: networkx in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo.skymap>=1.0.7->icarogw==2.0.1) (2.8.8)
# Requirement already satisfied: statsmodels>=0.7.0 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ChainConsumer->icarogw==2.0.1) (0.13.5)
# Requirement already satisfied: six in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from astroplan>=0.7->ligo.skymap>=1.0.7->icarogw==2.0.1) (1.16.0)
# Requirement already satisfied: pyerfa>=2.0 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from astropy->healpy>=1.16.2->icarogw==2.0.1) (2.0.0.1)
# Requirement already satisfied: PyYAML>=3.13 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from astropy->healpy>=1.16.2->icarogw==2.0.1) (6.0)
# Requirement already satisfied: packaging>=19.0 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from astropy->healpy>=1.16.2->icarogw==2.0.1) (20.9)
# Requirement already satisfied: future>=0.15.0 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (0.18.2)
# Requirement already satisfied: safe-netrc>=1.0.0 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (1.0.0)
# Requirement already satisfied: igwn-auth-utils>=0.3.1 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (0.3.1)
# Requirement already satisfied: cryptography<=36.0.2,>=1.7.2 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (36.0.2)
# Requirement already satisfied: requests>=2.6.0 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (2.28.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from matplotlib>=2.1->bilby>=2.1.0->icarogw==2.0.1) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from matplotlib>=2.1->bilby>=2.1.0->icarogw==2.0.1) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from matplotlib>=2.1->bilby>=2.1.0->icarogw==2.0.1) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from matplotlib>=2.1->bilby>=2.1.0->icarogw==2.0.1) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from matplotlib>=2.1->bilby>=2.1.0->icarogw==2.0.1) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from matplotlib>=2.1->bilby>=2.1.0->icarogw==2.0.1) (2.8.2)
# Requirement already satisfied: lscsoft-glue in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from python-ligo-lw>=1.8.0->ligo.skymap>=1.0.7->icarogw==2.0.1) (3.0.1)
# Collecting packaging>=19.0
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# Requirement already satisfied: patsy>=0.5.2 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from statsmodels>=0.7.0->ChainConsumer->icarogw==2.0.1) (0.5.3)
# Requirement already satisfied: cffi>=1.12 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from cryptography<=36.0.2,>=1.7.2->ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (1.15.1)
# Requirement already satisfied: scitokens>=1.7.0 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from igwn-auth-utils>=0.3.1->ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (1.7.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from requests>=2.6.0->ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from requests>=2.6.0->ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from requests>=2.6.0->ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from requests>=2.6.0->ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (2022.9.24)
# Requirement already satisfied: pyRXP in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from lscsoft-glue->python-ligo-lw>=1.8.0->ligo.skymap>=1.0.7->icarogw==2.0.1) (3.0.1)
# Requirement already satisfied: pyOpenSSL in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from lscsoft-glue->python-ligo-lw>=1.8.0->ligo.skymap>=1.0.7->icarogw==2.0.1) (22.0.0)
# Requirement already satisfied: pycparser in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from cffi>=1.12->cryptography<=36.0.2,>=1.7.2->ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (2.21)
# Requirement already satisfied: PyJWT>=1.6.1 in /home/simone/anaconda3/envs/igwn-py38/lib/python3.8/site-packages (from scitokens>=1.7.0->igwn-auth-utils>=0.3.1->ligo-gracedb>=2.0.1->ligo.skymap>=1.0.7->icarogw==2.0.1) (2.6.0)
# Building wheels for collected packages: icarogw, ChainConsumer
#   Building wheel for icarogw (setup.py) ... done
#   Created wheel for icarogw: filename=icarogw-2.0.1-py3-none-any.whl size=47387 sha256=55b5a9874abfbc27f6172e56baf50afb63e9147df665a744421966ae5cbb86dc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bdsn8v56/wheels/be/50/53/11adf60e314527fb0cf740695bc738a08640c0e8cd89e055a4
#   Building wheel for ChainConsumer (setup.py) ... done
#   Created wheel for ChainConsumer: filename=ChainConsumer-0.34.0-py3-none-any.whl size=42758 sha256=9a07f88ad3b02b208edb786018959b97c1e7cf5ad999c29a35d7653a7c5a53c2
#   Stored in directory: /home/simone/.cache/pip/wheels/7a/89/75/00fda7c57b287bf91cd8a217b2c98305099fe4ec3ed36941a4
# Successfully built icarogw ChainConsumer
# Installing collected packages: mpmath, dynesty, packaging, healpy, ChainConsumer, bilby, ligo.skymap, icarogw
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.2.1
#     Uninstalling mpmath-1.2.1:
#       Successfully uninstalled mpmath-1.2.1
#   Attempting uninstall: dynesty
#     Found existing installation: dynesty 1.0.1
#     Uninstalling dynesty-1.0.1:
#       Successfully uninstalled dynesty-1.0.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
#   Attempting uninstall: healpy
#     Found existing installation: healpy 1.16.1
#     Uninstalling healpy-1.16.1:
#       Successfully uninstalled healpy-1.16.1
#   Attempting uninstall: bilby
#     Found existing installation: bilby 1.1.5
#     Uninstalling bilby-1.1.5:
#       Successfully uninstalled bilby-1.1.5
#   Attempting uninstall: ligo.skymap
#     Found existing installation: ligo.skymap 1.0.3
#     Uninstalling ligo.skymap-1.0.3:
#       Successfully uninstalled ligo.skymap-1.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cdsutils 1.6.0 requires nds2-client, which is not installed.
# cdsutils 1.6.0 requires python-ezca, which is not installed.
# poetry 1.1.15 requires packaging<21.0,>=20.4, but you have packaging 23.1 which is incompatible.
# Successfully installed ChainConsumer-0.34.0 bilby-2.1.1 dynesty-2.1.2 healpy-1.16.3 icarogw-2.0.1 ligo.skymap-1.0.7 mpmath-1.3.0 packaging-23.1

# %%
import matplotlib.pyplot as plt
import numpy as np
import icarogw
import shutil
import bilby
# Out:
# Config not imported, automatically decides between Numpy and Cupy
# CUPY NOT LOADED BACK TO NUMPY

# %% [markdown]
# ## Generation of mock data to use
#
# Our first task is to generate mock data to use in our analysis. We need to do it consistently with the assumptions that we have made. We first need to generate the events from the gaussian process.

# %%
T_obs = 1 # Observation time in seconds
Rx = 100 # Rate of samples per second
x_true = np.random.randn(int(Rx*T_obs)) # Generate values of x according to the rate
plt.hist(x_true,bins='auto',density=True,histtype='step')
plt.title('Distribution of events reaching our detectors')
plt.xlabel('x')
plt.ylabel('PDF')
# Out:
# Text(0, 0.5, 'PDF')

# %% [markdown]
# Next, we need to generate a noisy measure of $x$ according to the likelihood model $\mathcal{L}_{\rm noise}(y|x)$. Then on the generated value of $y$ we apply a selection cut. We assume that we can detect only the $y \in [-1,1]$.

# %%
plt.figure(figsize=(5.0,3.2))
y_measured = x_true + np.random.randn(len(x_true)) # Generate a noisy measure
idx = (y_measured>-1) & (y_measured<1)
y_measured = y_measured[idx]
print('You detected {:d} events out of the {:d} arrived'.format(len(y_measured),len(x_true)))
plt.hist(x_true,bins='auto',density=True,histtype='step',label='Events arrived')
plt.hist(x_true[idx],bins='auto',density=True,histtype='step',label='Events detected')
plt.ylabel('PDF')
plt.title(r'100 events in 1 second, $N_{{\rm obs}}={:d}$'.format(len(y_measured)))
pp=np.linspace(-1,1,100)
plt.fill_between(pp,np.zeros_like(pp),np.ones_like(pp)*1,alpha=0.1,color='gray',label='Detection area')
plt.xlabel('x')
plt.tight_layout()
plt.legend()
plt.ylim([0,1])
# Out:
# You detected 57 events out of the 100 arrived
# (0.0, 1.0)

# %% [markdown]
# Now, the last step is to recgnise that we do not perfectly know $x$ for our events, instead we know $y$ and we are often provided with posterior samples on $x$. Namely, we are provided with samples of $x$ from the posterior
#
# $$p(x|y)\propto \mathcal{L}_{\rm noise}(y|x)\pi(x)$$
#
# if we generate posterior samples on $x$ using a flat prior, for this particular case it is trivial to see that the posterior samples of $x$ will be gaussian distributed around the value of $y$.

# %%
x_PE = []

for i in range(len(y_measured)):
    gsampler = bilby.core.prior.Normal(mu=y_measured[i],sigma=1.)
    x_PE.append(gsampler.sample(5000)) # Generate gaussian distribuited posterior samples

# %% [markdown]
# ## The hierachical likelihood for the example
#
# The hierarchical likelihood for the example above is given by
#
# $$\mathcal{L}(\vec{y}|\mu_*) = e^{-N_{\rm exp}} \prod_{i}^{N_{\rm obs}} \int dx dt \mathcal{L}_{\rm noise}(y_i|x) \frac{dN}{dx dt} $$
#
# where $\frac{dN}{dx dt}$ is the sample rate generation by the orginal gaussian process. We said that by hypothesis this is a gaussian process, so we can model
#
# $$\frac{dN}{dx dt}=R_x \mathcal{N}(x|\mu_*,\sigma^2)$$.
#
# Plugging in the likelihood above we have
#
# $$\mathcal{L}(\vec{y}|\mu_*) = e^{-N_{\rm exp}} \prod_{i}^{N_{\rm obs}} \int dx dt \mathcal{L}_{\rm noise}(y_i|x) R_x \mathcal{N}(x|\mu_*,\sigma^2) $$
#
# $$\mathcal{L}(\vec{y}|\mu_*) = e^{-N_{\rm exp}} \prod_{i}^{N_{\rm obs}} T_{\rm obs} \int dx R_x \mathcal{L}_{\rm det}(y_i|x)  \mathcal{N}(x|\mu_*,\sigma^2) $$.
#
# The expected number of detections $N_{\rm exp}$ can be calculated as
#
# $$N_{\rm exp} = T_{\rm obs} \int dx p_{\rm det}(x) R_x \mathcal{N}(x|\mu_*,\sigma^2)$$.
#
# ### How we calculate the integral of the likelihood
#
# We do it numerically, as we said we are provided with posterior samples on $x$ from the likelihood of the noise. Using the Bayes theorem we can write
#
# $$\mathcal{L}(\vec{y}|\mu_*) = e^{-N_{\rm exp}} \prod_{i}^{N_{\rm obs}} T_{\rm obs} \int dx R_x \frac{p(x|y_i)}{\pi(x)}  \mathcal{N}(x|\mu_*,\sigma^2) $$
#
# $$\mathcal{L}(\vec{y}|\mu_*) \approx e^{-N_{\rm exp}} \prod_{i}^{N_{\rm obs}}  \frac{T_{\rm obs}}{N_s}\sum_j^{N_s} R_x \frac{\mathcal{N}(x_j|\mu_*,\sigma^2)}{\pi(x_j)}   $$
#
# ### How we calculate $N_{\rm exp}$
#
# This number is computed thanks to `injections`, the idea is basically to simulate $N_{\rm gen}$ sources, where $N_{\rm gen}$ is large and then record all the $N_{\rm det}$ injections that you are able to detect. Now, the injections are drawn from a prior $\pi_{\rm inj}(x)$, which is not the model for which we are trying to evaluate the selection bias, so we need to reweight them. We can calculate
#
# $$N_{\rm exp}=\frac{T_{\rm obs}}{N_{\rm gen}} \sum_j^{N_{\rm det}} R_x \frac{\mathcal{N}(x_j|\mu_*,\sigma^2)}{\pi(x_j)}$$

# %%
plt.figure(figsize=(5.0,3.2))
Ngen = 100000 # Ngen for the injections
x_injections = np.random.uniform(-6,6,Ngen) # Generates the x samples from a distributions which I think can cover all the detectable cases
y_measured = x_injections + np.random.randn(len(x_injections)) # Generate a measured value of y
idx = (y_measured>-1) & (y_measured<1) # Check what we can detect
y_measured = y_measured[idx]
print('You detected {:d} events out of the {:d} arrived'.format(len(y_measured),len(x_injections)))
plt.hist(x_injections,bins='auto',density=True,histtype='step',label='Injected')
plt.hist(x_injections[idx],bins='auto',density=True,histtype='step',label='Detected')
pp=np.linspace(-1,1,100)
plt.fill_between(pp,np.zeros_like(pp),np.ones_like(pp)*.6,alpha=0.1,color='gray',label='Detection area')
plt.xlabel('x')
plt.legend()
plt.ylim([0,.6])
plt.ylabel('PDF')
plt.title(r'$N_{{\rm gen}}=10^5$ injections, $N_{{\rm det}}={:d}$'.format(len(y_measured)))
plt.tight_layout()
# Out:
# You detected 16612 events out of the 100000 arrived

# %% [markdown]
# ### What does icarogw want?
#
# icarogw wants you to tell how to calculate the rate per time for your model, i.e. it wants a rate class object that tell how to calculate
#
# $$w_i \equiv R_x\frac{\mathcal{N}(x_j|\mu_*,\sigma^2)}{\pi(x_j)}$$

# %%
import bilby

class my_gaussian_rate(object):
    '''
    A class for the rate of the gaussian example
    '''
    def __init__(self,scale_free=False):
        self.scale_free = scale_free # The class needs to have a scale_free flag
        if scale_free:
            self.population_parameters =  ['mu_star'] # Population parameters
        else:
            self.population_parameters =  ['mu_star','Rx'] # Population parameters if you want the scale-free version
        self.PEs_parameters = ['x'] # Events parameters, in this case we just have x
        self.injections_parameters = ['x'] # Events parameters, in this case we just have x
        
    def update(self,**kwargs): # We need a method that updates the pop model
        self.gmod = icarogw.priors.TruncatedGaussian(ming=-20,maxg=20.,meang=kwargs['mu_star'],sigmag=1.)   
        if not self.scale_free:
            self.Rx = kwargs['Rx'] # Save Rx
        
    def log_rate_PE(self,prior,**kwargs): # Tells us how to calculate the log of the rate for the PE
        # prior is the prior that you applied to generate PE, written in the variable x
        log_weights = self.gmod.log_pdf(kwargs['x'])-np.log(prior)
        if not self.scale_free:
            log_out = log_weights + np.log(self.Rx)
        else:
            log_out = log_weights
        return log_out
    
    def log_rate_injections(self,prior,**kwargs): # Tells us how to calculate the log of the rate for the injections
        # prior is the prior that you applied to generate injections, written in the variable x
        return self.log_rate_PE(prior,**kwargs)
    
myrate = my_gaussian_rate() # Initialize the rate model

# %%
# Icarogw wants that you store all the PE in a dict of posterior_samples classes

posterior_dict = {}
for i in range(len(x_PE)): # Loop on all the events you detect
    posterior_dict[str(i)] = icarogw.posterior_samples.posterior_samples({'x':x_PE[i]}, # You need to provide the PE in a dict, IMPORTANT field of the dict is
                                                                         # equal to the variable needed to evaluate the rate, i.e. x
                                                                         prior=np.ones(5000) # PE have been generated with uniform prior in x, so here 
                                                                         # I pass a constant. NOT IMPORTANT if not normalized
                                                                        )
posterior_dict=icarogw.posterior_samples.posterior_samples_catalog(posterior_dict)

# %%
# Icarogw wants the injections to evaluate the selection bias to be stored
injections = icarogw.injections.injections({'x':x_injections}, # Same logic as the posterior samples class
                                           prior=np.ones_like(x_injections)/12, # Prior used for the injections, IMPORTANT need to be correctly normalized
                                           ntotal=Ngen, # Number of generated injections
                                           Tobs=1.) # Observation time in units compatible with Rx)
injections.update_cut(idx) # We apply the cut on the detected injections from before
myrate.update(Rx=100.,mu_star=0.) # We update the rate model, note this is the true model
injections.update_weights(myrate) # We update the weights of the injections 
Nexp = injections.expected_number_detections() # We calculate the expected number of detections
                                           
print('Example, for the true model you would expect {:f} detections in 1 second'.format(Nexp))
print('The effective number of injections used to calculate this number is {:f}'.format(injections.effective_injections_number()))
# Out:
# Example, for the true model you would expect 52.036104 detections in 1 second
# The effective number of injections used to calculate this number is 15788.808421

# %%
# We define the hierarchical likelihood. This is a classical Bilby likelihood
likelihood = icarogw.likelihood.hierarchical_likelihood(posterior_dict, #Posterior samples dict
                                                        injections, # Injections class
                                                        myrate, # Rate model
                                                        nparallel=100, # Number of PE to use per event
                                                        neffPE=10, # Number of effective PE for numerical stability
                                                       neffINJ=None # Number of effective injections
                                                       )
# Priors
prior = {'mu_star': bilby.core.prior.Uniform(-2,2),
        'Rx': bilby.core.prior.LogUniform(1e-1,1e3)}

# Run bilby
myres = bilby.run_sampler(likelihood,priors=prior,save=False)
# Out:
# 17:39 bilby INFO    : Running for label 'label', output will be saved to 'outdir'
# Using 100 samples from each 57 posteriors
# 17:39 bilby INFO    : Analysis priors:
# 17:39 bilby INFO    : mu_star=Uniform(minimum=-2, maximum=2, name=None, latex_label=None, unit=None, boundary=None)
# 17:39 bilby INFO    : Rx=LogUniform(minimum=0.1, maximum=1000.0, name=None, latex_label=None, unit=None, boundary=None)
# 17:39 bilby INFO    : Analysis likelihood class: <class 'icarogw.likelihood.hierarchical_likelihood'>
# 17:39 bilby INFO    : Analysis likelihood noise evidence: nan
# 17:39 bilby INFO    : Single likelihood evaluation took 7.310e-04 s
# 17:39 bilby INFO    : Using sampler Dynesty with kwargs {'nlive': 500, 'bound': 'live', 'sample': 'act-walk', 'periodic': None, 'reflective': None, 'update_interval': 600, 'first_update': None, 'npdim': None, 'rstate': None, 'queue_size': 1, 'pool': None, 'use_pool': None, 'live_points': None, 'logl_args': None, 'logl_kwargs': None, 'ptform_args': None, 'ptform_kwargs': None, 'gradient': None, 'grad_args': None, 'grad_kwargs': None, 'compute_jac': False, 'enlarge': None, 'bootstrap': None, 'walks': 100, 'facc': 0.2, 'slices': None, 'fmove': 0.9, 'max_move': 100, 'update_func': None, 'ncdim': None, 'blob': False, 'save_history': False, 'history_filename': None, 'maxiter': None, 'maxcall': None, 'dlogz': 0.1, 'logl_max': inf, 'n_effective': None, 'add_live': True, 'print_progress': True, 'print_func': <bound method Dynesty._print_func of <bilby.core.sampler.dynesty.Dynesty object at 0x7fab56833ac0>>, 'save_bounds': False, 'checkpoint_file': None, 'checkpoint_every': 60, 'resume': False}
# 17:39 bilby INFO    : Checkpoint every check_point_delta_t = 600s
# 17:39 bilby INFO    : Using dynesty version 2.1.2
# 17:39 bilby INFO    : Using the bilby-implemented rwalk sampling tracking the autocorrelation function and thinning by 2 with maximum length 10000
# 17:39 bilby INFO    : Resume file outdir/label_resume.pickle does not exist.
# 17:39 bilby INFO    : Generating initial points from the prior
# 1it [00:00, ?it/s]
# 17:40 bilby INFO    : Written checkpoint file outdir/label_resume.pickle
# 17:40 bilby INFO    : Rejection sampling nested samples to obtain 1300 posterior samples
# 17:40 bilby INFO    : Sampling time: 0:00:48.518387
# 17:40 bilby INFO    : Summary of results:
# nsamples: 1300
# ln_noise_evidence:    nan
# ln_evidence: 129.244 +/-  0.108
# ln_bayes_factor:    nan +/-  0.108

# %%
shutil.rmtree('outdir')

# %%
myres.plot_corner(truths={'Rx':100.,'mu_star':0.})

# %%
from chainconsumer import ChainConsumer

c = ChainConsumer()

c.add_chain(np.column_stack([myres.posterior['mu_star'].to_numpy()
                             ,myres.posterior['Rx'].to_numpy()]), 
            parameters=[r"$\mu_*$", r"$R_x$"])

c.configure(linestyles=['solid'], linewidths=[1.0],
            shade=[True], shade_alpha=[0.2],sigma2d=False,
           sigmas=[1.0,1.645])

fig = c.plotter.plot(figsize="column",truth=[0,100])
plt.tight_layout()
